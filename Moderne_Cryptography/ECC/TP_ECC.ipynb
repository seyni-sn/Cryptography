# %%
R=RealField()
E=EllipticCurve(R,[0,6,0,6,5]) 
Courbe=E.plot()
Courbe
#E.discriminant() , E.j_invariant()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
Fp=FiniteField(next_prime(2^4))
E=EllipticCurve(Fp,[0,6,0,6,5])
#E.plot()

Fp, E,E.discriminant(),E.j_invariant()
# Out:
# (Finite Field of size 17,
#  Elliptic Curve defined by y^2 = x^3 + 6*x^2 + 6*x + 5 over Finite Field of size 17,
#  14,
#  6)

# %%
f(x)=(x+1)^2*(x+5)
f(x).expand()
# Out:
# x^3 + 7*x^2 + 11*x + 5

# %%
var(x)
f=(x+8)*(x+1)*(x-2)
f.expand()
# Out:
# x^3 + 7*x^2 - 10*x - 16

# %%
R=RealField()
E=EllipticCurve(R,[0,7,0,-10,-16]) 
E.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
Fp=FiniteField(7)
a=Fp(1)
b=Fp(1)
E=EllipticCurve(Fp,[a,b])
E, E.cardinality(), E.points()
G=E.gens()[0]
G, 2*G, 3*G, 4*G,5*G , G.order()
# Out:
# ((2 : 5 : 1), (0 : 6 : 1), (0 : 1 : 1), (2 : 2 : 1), (0 : 1 : 0), 5)
